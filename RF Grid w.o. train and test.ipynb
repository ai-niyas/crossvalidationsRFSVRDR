# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],'max_features': [1.0], 'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3, n_jobs=-1)

# %%
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3,n_jobs=-1)

# %%
# fitting the model for grid search without training and test data split
grid.fit(indep, dep)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [1.0], 'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 1.0, 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.065627      0.011411         0.011232        0.007193
# 1       0.564673      0.053591         0.016220        0.003228
# 2       0.291472      0.024121         0.002465        0.001362
# 3       2.860215      0.230720         0.013738        0.006593
# 4       0.061380      0.013325         0.003127        0.006255
# 5       0.700544      0.026319         0.028012        0.020267
# 6       0.093503      0.017040         0.003365        0.006730
# 7       0.876745      0.114477         0.016475        0.005809
#
#   param_criterion  param_max_features  param_n_estimators  \
# 0   squared_error                 1.0                  10
# 1   squared_error                 1.0                 100
# 2  absolute_error                 1.0                  10
# 3  absolute_error                 1.0                 100
# 4    friedman_mse                 1.0                  10
# 5    friedman_mse                 1.0                 100
# 6         poisson                 1.0                  10
# 7         poisson                 1.0                 100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'squared_error', 'max_features':...           0.843553
# 1  {'criterion': 'squared_error', 'max_features':...           0.849360
# 2  {'criterion': 'absolute_error', 'max_features'...           0.829498
# 3  {'criterion': 'absolute_error', 'max_features'...           0.839465
# 4  {'criterion': 'friedman_mse', 'max_features': ...           0.832704
# 5  {'criterion': 'friedman_mse', 'max_features': ...           0.847953
# 6  {'criterion': 'poisson', 'max_features': 1.0, ...           0.842767
# 7  {'criterion': 'poisson', 'max_features': 1.0, ...           0.847889
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.756662           0.852697           0.806697           0.826045
# 1           0.773415           0.853015           0.821939           0.837661
# 2           0.757947           0.834885           0.829280           0.816627
# 3           0.767674           0.853520           0.825903           0.835663
# 4           0.769811           0.829917           0.808399           0.826919
# 5           0.771655           0.859246           0.820195           0.837284
# 6           0.756612           0.833458           0.816837           0.819651
# 7           0.770080           0.858894           0.820029           0.838026
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.817131        0.034082                5
# 1         0.827078        0.028939                2
# 2         0.813647        0.028489                7
# 3         0.824445        0.029738                4
# 4         0.813550        0.023465                8
# 5         0.827267        0.030639                1
# 6         0.813865        0.030131                6
# 7         0.826983        0.031189                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:")) 
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 32
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[6485.275038]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
